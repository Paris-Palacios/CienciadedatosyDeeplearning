# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/banner_sdc.png">

# %% [markdown]
# <br><br><center><h1 style="font-size:2em;color:#2467C0"> Pasos principales para manejo de imágenes </h1></center>
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
#
#
# <td><img src="figuras/presentacion.png" align="middle" style="width:550px;"/></td>
# <td>
#
# **OpenCV** es una biblioteca libre desarrollada originalmente por Intel. Vio la luz en el año 1999. Escrita originalmente en C/C++, su mejor virtud es que es multiplataforma, se puede ejecutar en diferentes sistemas operativos (Linux, Windows, Mac OS X, Android e iOS). También la podemos utilizar en diferentes lenguajes de programación como Java, Objective C, C# y *Python*.
#
# Quizás sea la biblioteca de visión artificial más importante y más usada. Es utilizada por universidades, empresas y gente del movimiento Maker para dar rienda suelta a su imaginación al tratarse de un software libre.
#
# En este notebook comenzaremos con el tratamiento de imágenes en Python mediante esta librería, más específicamente vamos a ver como cargar o  leer una imagen, conversión a blanco y negro, filtros y otras operaciones que serán útiles dentro del curso.
#
#
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # 0. Librerías básicas

# %%
#Librerías básicas de esta notebook
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

# %% [markdown]
# # Parte 1

# %% [markdown]
# ## Abrir una imagen

# %% [markdown]
# ###  "Hola mundo“ (Método oficial)

# %%
# Al ejecutar esta celda se abre una ventana externa, es necesario cerrar esa ventana
# para continuar la ejecución de las siguientes celdas.
img = cv.imread('figuras/teotihuacan.jpg')
cv.imshow("Imagen de sitio arqueológico",img)
cv.waitKey()
cv.destroyAllWindows()

# %% [markdown]
# ###  "Hola mundo“ (Recomendado para openCV en Jupyter)

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Shape: propiedades básicas

# %% [markdown]
# El siguiente código muestra como ver las propiedades de una imagen: alto, ancho y
# numero de canales

# %%
img = cv.imread('figuras/teotihuacan.jpg')
print("Función shape",img.shape)
print("alto:",img.shape[0],"pixeles")
print("ancho:", img.shape[1],"pixeles" )
print("canales: ", img.shape[2])
# Out:
# Función shape (700, 1200, 3)
# alto: 700 pixeles
# ancho: 1200 pixeles
# canales:  3

# %% [markdown]
# ## Conversión a escala de grises en openCV

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img_gray,cmap='gray')
plt.show()

# %% [markdown]
# ### Grid y barra de escala de grises

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img_gray,cmap='gray')
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# ### Dimensiones de una imagen en escala de grises

# %% [markdown]
# Cuando hemos convertido la imagen a escala de grises,
# desaparecen los canales RGB y solo nos queda un arreglo de dos
# dimensiones

# %%
print("Función shape",img_gray.shape)
print("alto:",img_gray.shape[0],"pixeles")
print("ancho:", img_gray.shape[1],"pixeles" )
# Out:
# Función shape (700, 1200)
# alto: 700 pixeles
# ancho: 1200 pixeles

# %% [markdown]
# ### Cambiar el color a un pixel

# %%
img_gray[0,0]=0
img_gray[70,250]=0
plt.imshow(img_gray,cmap='gray')
plt.grid()
plt.show()

# %% [markdown]
# ### Cambiando zonas a negro y blanco

# %%
img_gray[0:150,200:300]=0
img_gray[300:350,400:450]=255
plt.imshow(img_gray,cmap='gray')
plt.grid()
plt.show()

# %% [markdown]
# ### Cortando una parte de la imagen

# %%
corner = img_gray[0:150, 0:400]
plt.imshow(corner,cmap='gray')
plt.show()

# %% [markdown]
# ## Filtros

# %% [markdown]
# Media

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
filtro_media=cv.blur(img_gray,(3,3) )
plt.imshow(filtro_media,cmap='gray')
plt.show()

# %% [markdown]
# Mediana

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
filtro_mediana=cv.medianBlur(img_gray,3)
plt.imshow(filtro_mediana,cmap='gray')
plt.show()

# %% [markdown]
# Gauss

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
filtro_gauss=cv.GaussianBlur(img_gray,(3,3),0)
plt.imshow(filtro_gauss,cmap='gray')
plt.show()

# %% [markdown]
# ### Ejemplo de aplicación del filtro Mediana

# %% [markdown]
# Imagen original

# %%
img = cv.imread('figuras/aplicacion.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img,cmap='gray')
plt.show()

# %% [markdown]
# Imagen con mediana

# %%
img = cv.imread('figuras/aplicacion.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
filtro_mediana=cv.medianBlur(img_gray,3)
plt.imshow(filtro_mediana,cmap='gray')
plt.show()

# %% [markdown]
# ## Thresholding

# %% [markdown]
# Thresholding es la binarización de una imagen
# (conversión a blanco/negro)
# Los pasos son los siguientes
# 1. Cargar la imagen
# 2. Convertir a escala de grises
# 3. Aplicar el filtro Gaussiano
# 4. Aplicar la binarización

# %% [markdown]
# T=50

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
img_gauss=cv.GaussianBlur(img_gray ,(3,3),0)
thr, img_thr = cv.threshold(img_gauss,50,255,cv.THRESH_BINARY)
plt.imshow(img_thr,cmap='gray')
plt.show()

# %% [markdown]
# T=160

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
img_gauss=cv.GaussianBlur(img_gray ,(3,3),0)
thr, img_thr = cv.threshold(img_gauss,160,255,cv.THRESH_BINARY)
plt.imshow(img_thr,cmap='gray')
plt.show()

# %%
T=200

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
img_gauss=cv.GaussianBlur(img_gray ,(3,3),0)
thr, img_thr = cv.threshold(img_gauss,120,255,cv.THRESH_BINARY)
plt.imshow(img_thr,cmap='gray')
plt.show()

# %% [markdown]
# ## Resize o cambio de tamaño

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
img_gauss=cv.GaussianBlur(img_gray ,(3,3),0)
thr, img_thr = cv.threshold(img_gauss,120,255,cv.THRESH_BINARY)
alto=img.shape[0]
ancho=img.shape[1]
ratio=.2
img_r = cv.resize(img_thr,(int(ancho*ratio),int(alto*ratio)), interpolation=cv.INTER_NEAREST)
plt.imshow( img_r,cmap='gray')
plt.show()

# %% [markdown]
# ## Todas las operaciones

# %%
img = cv.imread('figuras/teotihuacan.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
img_gauss=cv.GaussianBlur(img_gray ,(3,3),0)
thr, img_thr = cv.threshold(img_gauss,160,255,cv.THRESH_BINARY)
alto=img.shape[0]
ancho=img.shape[1]
ratio=.2
img_r = cv.resize(img_thr,(int(ancho*ratio),int(alto*ratio)), interpolation=cv.INTER_NEAREST)

plt.figure(figsize=(10,6))
plt.subplot(2,3,1)
plt.imshow(img)
plt.title("Imagen original")
plt.subplot(2,3,2)
plt.imshow(img_gray, cmap = 'gray')
plt.title("Imagen en escala de grises")
plt.subplot(2,3,3)
plt.imshow(img_gauss, cmap = 'gray')
plt.title("Imagen con filtro gaussiano")
plt.subplot(2,3,4)
plt.imshow(img_thr, cmap = 'gray')
plt.title("Imagen con thresholding")
plt.subplot(2,3,5)
plt.imshow(img_r, cmap = 'gray')
plt.title("Imagen con el ratio= " + str(ratio))
plt.show()

# %% [markdown]
# ## Parte 2

# %% [markdown]
# ### Operaciones aritmeticas en imagenes

# %% [markdown]
# #### Aumentar la intensidad

# %%
M = np.ones(img.shape, dtype="uint8") * 100
added = cv.add(img, M)
plt.imshow(added)

# %% [markdown]
# #### Disminuir la intensidad

# %%
M = np.ones(img.shape, dtype="uint8") * 50
subtracted = cv.subtract(img, M)
plt.imshow(subtracted)

# %% [markdown]
# #### Alta y baja intensidad

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
plt.imshow(img)
plt.title("Imagen original")
plt.subplot(1,3,2)
plt.imshow(added)
plt.title("Imagen con alta intensidad")
plt.subplot(1,3,3)
plt.imshow(subtracted)
plt.title("Imagen con baja intensidad")
plt.show()
