# %% [markdown]
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/banner_dl.png">

# %% [markdown]
# # TAREA

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv
import imutils

# %% [markdown]
# <div class="alert alert-success">
# 1. Utilizando el archivo figuras/dog_backpack.png, obtenga cada una de las salidas que se muestran a continuacion
#
# </div>

# %%
#1
img=cv.imread('figuras/dog_backpack.png')
plt.imshow(img)
plt.show()

# %%
#2
img=cv.imread('figuras/dog_backpack.png')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
#3
new_img = cv.flip(img, 0)
plt.imshow(new_img)
plt.show()

# %%
#4
new_img = cv.flip(img, 1)
plt.imshow(new_img)
plt.show()

# %%
#4
new_img = cv.flip(img, -1)
plt.imshow(new_img)
plt.show()

# %%
#5
img=cv.imread('figuras/dog_backpack.png')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img, pt1=(200,350) ,  pt2=(600,700) , color=(255,0,0) , thickness = 8);
plt.imshow(img)
plt.show()

# %%
img=cv.imread('figuras/dog_backpack.png')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img, pt1=(200,350) ,  pt2=(600,700) , color=(255,0,0) , thickness = 8);
plt.imshow(img)
plt.show()

# %%
#6
img=cv.imread('figuras/dog_backpack.png')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
puntos = np.array([ [400,400], [600,700], [250,700]  ] )
cv.polylines(img, [puntos], isClosed=True , color=(0,0,255) , thickness = 20 );
plt.imshow(img)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
#
# 2. Crear la imagen en color negro y  la figura geométrica.
#
#
# </div>

# %%
#600 Filas x 800 Columnas
canvas = np.zeros( shape=(600,800,3) , dtype=np.int16 )
puntos = np.array([ [300,100], [500,500], [100,400], [100,200]  ] )
cv.polylines(canvas, [puntos], isClosed=True , color=(0,255,0) , thickness = 6);
plt.imshow(canvas)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
#
# 3. Utilizando el archivo figuras/dog_backpack.png realizar la rotación cada 30 grados utilizando imutils.rotate e imutils.rotate_bound
#
#
# </div>

# %%
img = cv.imread('figuras/dog_backpack.png')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img_rot=imutils.rotate(img, angle=30)
plt.imshow(img_rot)
plt.show()

# %%
img_rot=imutils.rotate_bound(img, angle= -30)
plt.imshow(img_rot)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# 4. Utilizando el archivo figuras/monedas.jpeg, obtenga los bordes como se muestra a continuacion
#
# </div>

# %% [markdown]
# <img align="left" width="300"  float= "none" align="middle" src="figuras/mx_coins.png">

# %%
img = cv.imread('figuras/monedas.jpeg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img_gray=cv.cvtColor(img,cv.COLOR_RGB2GRAY)
img_gauss=cv.GaussianBlur(img_gray,(3,3,),0)
thr, img_thr = cv.threshold (img_gauss, 170,255, cv.THRESH_BINARY_INV ) 
contornos, _ =   cv.findContours(img_thr, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE )
cv.drawContours( img, contornos , -1 , (255,0,0), 2   )

plt.imshow(img)
plt.show()
