# %% [markdown]
# <!--Información del curso-->
# <!--Información del curso-->
# <img align="left" style="padding-right:10px;" src="figuras/banner_dl.png">

# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0"> Caso de estudio: Juegos Olimpicos  </h1></center>
#
# <center><h2 style="font-size:2em;color:#840700">  Pandas   </h4></center>
#
# <br>
# <table>
# <col width="550">
# <col width="450">
# <tr>
# <td><img src="figuras/WesM.png" align="left" style="width:500px"/></td>
# <td>
#
# * **Wes McKinney**, empezó a desarrollar Pandas en el año 2008 mientras trabajaba en *AQR Capital* [https://www.aqr.com/] por la necesidad que tenía de una herramienta flexible de alto rendimiento para realizar análisis cuantitativos en datos financieros.
# * Antes de dejar AQR convenció a la administración de la empresa de distribuir esta biblioteca bajo licencia de código abierto.
# * **Pandas** es un acrónimo de **PANel DAta analysiS**
#
#
# <br>
# </td>
# </tr>
# </table>

# %% [markdown]
# # Librerías
#
# Cargando las bibliotecas que necesitamos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduccion

# %% [markdown]
# * Pandas es un paquete de Python que proporciona estructuras de datos rápidas, flexibles y expresivas diseñadas para hacer que el trabajo con datos "relacionales" o "etiquetados" sea fácil e intuitivo.
# * Pretende ser el elemento fundamental de alto nivel para realizar análisis de datos prácticos y del mundo real en Python.
# * La documentación oficial de Pandas se puede encontrar en el siguiente link https://pandas.pydata.org/pandas-docs/stable/
#
#
# <img align="left" width=60% src="figuras/pandas2.jpeg">

# %% [markdown]
# Características principales de uso:
# * Ingestión de datos (Data ingestion)
# * Estadística descriptiva
# * Limpieza de datos
# * Visualización
# * Transformación de datos
# * Combinando DataFrames
# * Manejo datos utilizando una variable temporal

# %% [markdown]
# # Estructuras de datos en Pandas : Series y DataFrames
#
# Pandas proporciona dos tipos de datos fundamentales, para 1D (**Series**) y datos 2D (**DataFrame**).
#
#
# <img align="left" width=75% src="figuras/SeriesYDataFrame.png">

# %% [markdown]
# <img align="left" width=60% src="figuras/DataFrame.png">

# %% [markdown]
# En el nivel más básico, los objetos Pandas se pueden considerar como versiones mejoradas de matrices estructuradas NumPy en las que las filas y columnas se identifican con etiquetas en lugar de índices enteros simples.

# %% [markdown]
# # Librerías
#
# Cargando las bibliotecas que necesitamos

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Datos
# * Revisar las primeras líneas de los archivos
# * Utilizar las funciones de descripción e información para recopilar información estadística, tipos de datos, nombres de columnas y otra información.

# %%
#Cargar el archivo datos/athlete_events.csv en un dataframe llamado df_atletas
df_atletas= pd.read_csv("datos/athlete_events.csv")

# %%
#Revisar las primeras líneas de los archivos
df_atletas.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
#Tipos de datos en las columnas
df_atletas.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
# Encontrar los principales valores estadísticos 
df_atletas.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#Cargar el archivo datos/datasets_31029_40943_noc_regions.csv en un dataframe llamado df_paises
df_paises = pd.read_csv('datos/datasets_31029_40943_noc_regions.csv')

# %%
#Mostrar las primeras líneas
df_paises.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %% [markdown]
# ### 1 . Combinando los dataframes
# Combinar los dataframes **df_paises** y **df_atletas** en un dataframe llamado **df**.
#
# *Utilizar la columna 'NOC'*

# %%
#Utilizar pd.merge
df = pd.merge(df_paises , df_atletas, on='NOC')

# %%
#Mostrar las primeras líneas
df.head()
# Out:
#    NOC       region notes    ID                   Name Sex   Age  Height  \
# 0  AFG  Afghanistan   NaN   502      Ahmad Shah Abouwi   M   NaN     NaN
# 1  AFG  Afghanistan   NaN  1076  Jammal-ud-Din Affendi   M  28.0     NaN
# 2  AFG  Afghanistan   NaN  1101   Mohammad Anwar Afzal   M   NaN     NaN
# 3  AFG  Afghanistan   NaN  1745         Mohammad Aktar   M  17.0   156.0
# 4  AFG  Afghanistan   NaN  4628  Mohammad Daoud Anwary   M  22.0     NaN
#
#    Weight         Team        Games  Year  Season       City      Sport  \
# 0     NaN  Afghanistan  1956 Summer  1956  Summer  Melbourne     Hockey
# 1     NaN  Afghanistan  1936 Summer  1936  Summer     Berlin     Hockey
# 2     NaN  Afghanistan  1948 Summer  1948  Summer     London   Football
# 3    48.0  Afghanistan  1980 Summer  1980  Summer     Moskva  Wrestling
# 4     NaN  Afghanistan  1964 Summer  1964  Summer      Tokyo  Wrestling
#
#                                         Event Medal
# 0                         Hockey Men's Hockey   NaN
# 1                         Hockey Men's Hockey   NaN
# 2                     Football Men's Football   NaN
# 3  Wrestling Men's Light-Flyweight, Freestyle   NaN
# 4     Wrestling Men's Bantamweight, Freestyle   NaN

# %% [markdown]
# ### 2. Dataframe de medallas de oro
# Crear un dataframe solo de medallas de oro

# %%
#Mostrar los posibles valores  de la columna Medal
df['Medal'].unique()
# Out:
# array([nan, 'Bronze', 'Silver', 'Gold'], dtype=object)

# %%
#Crear el dataframe df_MedallasOro solo con medallas de oro.
df_MedallasOro = df[  df['Medal'] == 'Gold'  ]

# %%
df_MedallasOro.head(2)
# Out:
#      NOC   region notes     ID               Name Sex   Age  Height  Weight  \
# 449  ALG  Algeria   NaN  14046  Hassiba Boulmerka   F  24.0   158.0    49.0
# 666  ALG  Algeria   NaN  73857  Taoufik Makhloufi   M  24.0   170.0    67.0
#
#         Team        Games  Year  Season       City      Sport  \
# 449  Algeria  1992 Summer  1992  Summer  Barcelona  Athletics
# 666  Algeria  2012 Summer  2012  Summer     London  Athletics
#
#                               Event Medal
# 449  Athletics Women's 1,500 metres  Gold
# 666    Athletics Men's 1,500 metres  Gold

# %% [markdown]
# #####  Distribución de edades de medallas de oro

# %%
# Revisar si la columna Age tiene elementos nulos 
df_MedallasOro['Age'].isnull().any()
# Out:
# True

# %%
#Revisar los diferentes valores
df_MedallasOro['Age'].unique()
# Out:
# array([24., 29., 26., 23., 28., 22., 21., 30., 25., 20., 46., 31., 34.,
#        43., 27., 40., 35., 54., 32., 39., 33., 37., 18., 19., 17., 16.,
#        44., 38., 15., nan, 41., 45., 14., 59., 36., 50., 47., 49., 13.,
#        48., 52., 42., 53., 58., 56., 57., 51., 60., 55., 63., 64.])

# %%
#De manera general
df_MedallasOro.isnull().any()
# Out:
# NOC       False
# region    False
# notes      True
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal     False
# dtype: bool

# %%
# Eliminar las filas con 'nan' 
df_MedallasOro = df_MedallasOro.dropna( subset = ['Age'] )

# %%
#Mostrar nuevamente los posibles valores de la columna 'Age'
df_MedallasOro['Age'].unique()
# Out:
# array([24., 29., 26., 23., 28., 22., 21., 30., 25., 20., 46., 31., 34.,
#        43., 27., 40., 35., 54., 32., 39., 33., 37., 18., 19., 17., 16.,
#        44., 38., 15., 41., 45., 14., 59., 36., 50., 47., 49., 13., 48.,
#        52., 42., 53., 58., 56., 57., 51., 60., 55., 63., 64.])

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df_MedallasOro, x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(20,4))
sns.countplot(data=df_MedallasOro, x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
# ¿Cuantas personas mayores a 50 han ganado una medalla de oro?
df_MedallasOro['Age'][  df_MedallasOro['Age'] > 50 ].count()
# Out:
# 65

# %% [markdown]
# ##### ¿Qué disciplinas te permiten conseguir una medalla de oro después de los cincuenta?

# %%
#Mostrar las diferentes disciplinas (mayores a 50)
df_MedallasOro['Sport'][ df_MedallasOro['Age'] > 50 ].unique()
# Out:
# array(['Sailing', 'Equestrianism', 'Archery', 'Shooting',
#        'Art Competitions', 'Croquet', 'Alpinism', 'Curling', 'Roque'],
#       dtype=object)

# %%
deportes_m50 = df_MedallasOro['Sport'][ df_MedallasOro['Age'] > 50 ]
deportes_m50
# Out:
# 3117               Sailing
# 10144              Sailing
# 21199        Equestrianism
# 22182              Archery
# 22183              Archery
#                 ...
# 265281             Archery
# 265424            Shooting
# 265428    Art Competitions
# 265562             Archery
# 265768    Art Competitions
# Name: Sport, Length: 65, dtype: object

# %%
#Mostrar el número de ganadores por disciplina (mayores a 50)
plt.figure(figsize=(20,4))
sns.countplot(data=deportes_m50, x=deportes_m50)
# Out:
# <AxesSubplot:xlabel='Sport', ylabel='count'>

# %% [markdown]
# ### 3. Mujeres en atletismo

# %%
# Crear un dataframe para mujeres llamado df_women 
# Considerar solamente los juegos de verano

# %%
df_women = df[(df['Sex']=='F') & (df['Season']=='Summer')]
df_women.head()
# Out:
#      NOC       region notes      ID               Name Sex   Age  Height  \
# 57   AFG  Afghanistan   NaN   61961  Tahmina Kohistani   F  23.0   160.0
# 82   AFG  Afghanistan   NaN   99303      Friba Razayee   F  18.0   165.0
# 114  AFG  Afghanistan   NaN  132125  Robina Muqim Yaar   F  18.0   180.0
# 115  AFG  Afghanistan   NaN  132125  Robina Muqim Yaar   F  22.0   180.0
# 117  AFG  Afghanistan   NaN  133277      Kamia Yousufi   F  20.0   165.0
#
#      Weight         Team        Games  Year  Season            City  \
# 57     52.0  Afghanistan  2012 Summer  2012  Summer          London
# 82     70.0  Afghanistan  2004 Summer  2004  Summer          Athina
# 114    56.0  Afghanistan  2004 Summer  2004  Summer          Athina
# 115    56.0  Afghanistan  2008 Summer  2008  Summer         Beijing
# 117    55.0  Afghanistan  2016 Summer  2016  Summer  Rio de Janeiro
#
#          Sport                         Event Medal
# 57   Athletics  Athletics Women's 100 metres   NaN
# 82        Judo     Judo Women's Middleweight   NaN
# 114  Athletics  Athletics Women's 100 metres   NaN
# 115  Athletics  Athletics Women's 100 metres   NaN
# 117  Athletics  Athletics Women's 100 metres   NaN

# %%
#Crear un gráfico en el que colocamos el año (en el eje x) 
# y contamos el número de participantes por edición de los juegos

# %%
plt.figure(figsize=(20,6))
sns.countplot(data=df_women, x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
#Revisar el numero de participantes mujeres en 2016
df_women['Year'] [ df_women['Year'] == 2016 ].count()
# Out:
# 6203

# %%
#Revisar el numero de participantes mujeres en 2016 con medalla de oro
df_women['Year'] [ (df_women['Year'] == 2016) & (df_women['Medal'] == 'Gold') ].count()
# Out:
# 318

# %% [markdown]
# ### 4. Medallas de oro por país

# %%
# Encontrar los cinco países con mayor número de medallas de oro 
df_MedallasOro
# Out:
#         NOC    region notes      ID                                  Name Sex  \
# 449     ALG   Algeria   NaN   14046                     Hassiba Boulmerka   F
# 666     ALG   Algeria   NaN   73857                     Taoufik Makhloufi   M
# 690     ALG   Algeria   NaN   78805                    Nouria Mrah-Benida   F
# 708     ALG   Algeria   NaN   81861                    Noureddine Morceli   M
# 784     ALG   Algeria   NaN  112998                        Hocine Soltani   M
# ...     ...       ...   ...     ...                                   ...  ..
# 270693  ZIM  Zimbabwe   NaN   97036  Christine Seraphine "Chris" Prinsloo   F
# 270699  ZIM  Zimbabwe   NaN  101386              Sonia Robertson (Chick-)   F
# 270713  ZIM  Zimbabwe   NaN  115129        Anthea Dorine Stewart (Allin-)   F
# 270751  ZIM  Zimbabwe   NaN  127168                            Helen Volk   F
# 270756  ZIM  Zimbabwe   NaN  128977                 Linda Margaret Watson   F
#
#          Age  Height  Weight      Team        Games  Year  Season       City  \
# 449     24.0   158.0    49.0   Algeria  1992 Summer  1992  Summer  Barcelona
# 666     24.0   170.0    67.0   Algeria  2012 Summer  2012  Summer     London
# 690     29.0   162.0    54.0   Algeria  2000 Summer  2000  Summer     Sydney
# 708     26.0   175.0    60.0   Algeria  1996 Summer  1996  Summer    Atlanta
# 784     23.0   165.0    60.0   Algeria  1996 Summer  1996  Summer    Atlanta
# ...      ...     ...     ...       ...          ...   ...     ...        ...
# 270693  28.0   156.0    47.0  Zimbabwe  1980 Summer  1980  Summer     Moskva
# 270699  33.0   168.0    60.0  Zimbabwe  1980 Summer  1980  Summer     Moskva
# 270713  35.0   160.0    56.0  Zimbabwe  1980 Summer  1980  Summer     Moskva
# 270751  26.0   150.0    55.0  Zimbabwe  1980 Summer  1980  Summer     Moskva
# 270756  24.0   165.0    63.0  Zimbabwe  1980 Summer  1980  Summer     Moskva
#
#             Sport                           Event Medal
# 449     Athletics  Athletics Women's 1,500 metres  Gold
# 666     Athletics    Athletics Men's 1,500 metres  Gold
# 690     Athletics  Athletics Women's 1,500 metres  Gold
# 708     Athletics    Athletics Men's 1,500 metres  Gold
# 784        Boxing        Boxing Men's Lightweight  Gold
# ...           ...                             ...   ...
# 270693     Hockey           Hockey Women's Hockey  Gold
# 270699     Hockey           Hockey Women's Hockey  Gold
# 270713     Hockey           Hockey Women's Hockey  Gold
# 270751     Hockey           Hockey Women's Hockey  Gold
# 270756     Hockey           Hockey Women's Hockey  Gold
#
# [13223 rows x 17 columns]

# %%
df_MedallasOro['region'].value_counts().reset_index(name='Medal')
# Out:
#           index  Medal
# 0           USA   2627
# 1        Russia   1599
# 2       Germany   1293
# 3            UK    657
# 4         Italy    567
# ..          ...    ...
# 92       Kosovo      1
# 93  Puerto Rico      1
# 94         Peru      1
# 95       Panama      1
# 96       Jordan      1
#
# [97 rows x 2 columns]

# %%
df_MedallasOro['region'].value_counts().reset_index(name='Medal').head()
# Out:
#      index  Medal
# 0      USA   2627
# 1   Russia   1599
# 2  Germany   1293
# 3       UK    657
# 4    Italy    567

# %%
top_medallasOro= df_MedallasOro['region'].value_counts().reset_index(name='Medal').head()

# %%
g = sns.catplot(x="index", y="Medal", data=top_medallasOro,
                height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_xlabels("5 países principales ")
g.set_ylabels("Numero de medallas ")
plt.title('Medallas por país ')
# Out:
# Text(0.5, 1.0, 'Medallas por país ')

# %% [markdown]
# # Ejercicio
#
# **Parte 1**
#
# Crear un dataframe para México llamado df_Mexico (solo datos de México)

# %% [markdown]
# <div class="alert alert-success">
#
# 1. Mostrar la distribución de edades en forma grafica.
# </div>

# %%
df_Mexico= df[ ( df['region'] == 'Mexico' ) ]

# %%
df_Mexico
# Out:
#         NOC  region notes      ID                               Name Sex  \
# 167721  MEX  Mexico   NaN      82             Enrique Abaroa Martnez   M
# 167722  MEX  Mexico   NaN      98                      Hctor Abaunza   M
# 167723  MEX  Mexico   NaN      98                      Hctor Abaunza   M
# 167724  MEX  Mexico   NaN      98                      Hctor Abaunza   M
# 167725  MEX  Mexico   NaN     405           Jos Javier Abella Fanjul   M
# ...     ...     ...   ...     ...                                ...  ..
# 170596  MEX  Mexico   NaN  134358                 Omar Zepeda de Lon   M
# 170597  MEX  Mexico   NaN  134383            Jos Luis Zertuche Chvez   M
# 170598  MEX  Mexico   NaN  134967                Pablo Zierold Reyes   M
# 170599  MEX  Mexico   NaN  135062  Antonio Lus "Zinha" Naelson Matas   M
# 170600  MEX  Mexico   NaN  135421    Goretti Alejandra Zumaya Flores   F
#
#          Age  Height  Weight    Team        Games  Year  Season  \
# 167721  26.0   183.0    75.0  Mexico  2000 Summer  2000  Summer
# 167722  30.0   169.0    75.0  Mexico  1968 Summer  1968  Summer
# 167723  30.0   169.0    75.0  Mexico  1968 Summer  1968  Summer
# 167724  30.0   169.0    75.0  Mexico  1968 Summer  1968  Summer
# 167725  22.0   176.0    66.0  Mexico  2016 Summer  2016  Summer
# ...      ...     ...     ...     ...          ...   ...     ...
# 170596  39.0   175.0    70.0  Mexico  2016 Summer  2016  Summer
# 170597  27.0   172.0    71.0  Mexico  2000 Summer  2000  Summer
# 170598   NaN   173.0     NaN  Mexico  1932 Summer  1932  Summer
# 170599  28.0   163.0    66.0  Mexico  2004 Summer  2004  Summer
# 170600  19.0   165.0    65.0  Mexico  2016 Summer  2016  Summer
#
#                   City      Sport                                   Event  \
# 167721          Sydney     Tennis                    Tennis Men's Doubles
# 167722     Mexico City    Fencing          Fencing Men's Foil, Individual
# 167723     Mexico City    Fencing                Fencing Men's Foil, Team
# 167724     Mexico City    Fencing               Fencing Men's Sabre, Team
# 167725  Rio de Janeiro   Football                 Football Men's Football
# ...                ...        ...                                     ...
# 170596  Rio de Janeiro  Athletics      Athletics Men's 50 kilometres Walk
# 170597          Sydney     Boxing         Boxing Men's Light-Middleweight
# 170598     Los Angeles   Swimming  Swimming Men's 200 metres Breaststroke
# 170599          Athina   Football                 Football Men's Football
# 170600  Rio de Janeiro   Shooting   Shooting Women's Air Rifle, 10 metres
#
#        Medal
# 167721   NaN
# 167722   NaN
# 167723   NaN
# 167724   NaN
# 167725   NaN
# ...      ...
# 170596   NaN
# 170597   NaN
# 170598   NaN
# 170599   NaN
# 170600   NaN
#
# [2880 rows x 17 columns]

# %%
plt.figure(figsize=(22,10))
sns.histplot(data=df_Mexico, x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(22,10))
sns.countplot(data=df_Mexico, x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# <div class="alert alert-success">
#
# 2. Mostrar la participación de deportistas mexicanos en las competencias de Verano (en los diferentes años) en forma grafica.
# </div>

# %%
df_Mexico_Summer = df_Mexico[ (df_Mexico['Season'] == 'Summer') ]
df_Mexico_Summer
# Out:
#         NOC  region notes      ID                               Name Sex  \
# 167721  MEX  Mexico   NaN      82             Enrique Abaroa Martnez   M
# 167722  MEX  Mexico   NaN      98                      Hctor Abaunza   M
# 167723  MEX  Mexico   NaN      98                      Hctor Abaunza   M
# 167724  MEX  Mexico   NaN      98                      Hctor Abaunza   M
# 167725  MEX  Mexico   NaN     405           Jos Javier Abella Fanjul   M
# ...     ...     ...   ...     ...                                ...  ..
# 170596  MEX  Mexico   NaN  134358                 Omar Zepeda de Lon   M
# 170597  MEX  Mexico   NaN  134383            Jos Luis Zertuche Chvez   M
# 170598  MEX  Mexico   NaN  134967                Pablo Zierold Reyes   M
# 170599  MEX  Mexico   NaN  135062  Antonio Lus "Zinha" Naelson Matas   M
# 170600  MEX  Mexico   NaN  135421    Goretti Alejandra Zumaya Flores   F
#
#          Age  Height  Weight    Team        Games  Year  Season  \
# 167721  26.0   183.0    75.0  Mexico  2000 Summer  2000  Summer
# 167722  30.0   169.0    75.0  Mexico  1968 Summer  1968  Summer
# 167723  30.0   169.0    75.0  Mexico  1968 Summer  1968  Summer
# 167724  30.0   169.0    75.0  Mexico  1968 Summer  1968  Summer
# 167725  22.0   176.0    66.0  Mexico  2016 Summer  2016  Summer
# ...      ...     ...     ...     ...          ...   ...     ...
# 170596  39.0   175.0    70.0  Mexico  2016 Summer  2016  Summer
# 170597  27.0   172.0    71.0  Mexico  2000 Summer  2000  Summer
# 170598   NaN   173.0     NaN  Mexico  1932 Summer  1932  Summer
# 170599  28.0   163.0    66.0  Mexico  2004 Summer  2004  Summer
# 170600  19.0   165.0    65.0  Mexico  2016 Summer  2016  Summer
#
#                   City      Sport                                   Event  \
# 167721          Sydney     Tennis                    Tennis Men's Doubles
# 167722     Mexico City    Fencing          Fencing Men's Foil, Individual
# 167723     Mexico City    Fencing                Fencing Men's Foil, Team
# 167724     Mexico City    Fencing               Fencing Men's Sabre, Team
# 167725  Rio de Janeiro   Football                 Football Men's Football
# ...                ...        ...                                     ...
# 170596  Rio de Janeiro  Athletics      Athletics Men's 50 kilometres Walk
# 170597          Sydney     Boxing         Boxing Men's Light-Middleweight
# 170598     Los Angeles   Swimming  Swimming Men's 200 metres Breaststroke
# 170599          Athina   Football                 Football Men's Football
# 170600  Rio de Janeiro   Shooting   Shooting Women's Air Rifle, 10 metres
#
#        Medal
# 167721   NaN
# 167722   NaN
# 167723   NaN
# 167724   NaN
# 167725   NaN
# ...      ...
# 170596   NaN
# 170597   NaN
# 170598   NaN
# 170599   NaN
# 170600   NaN
#
# [2810 rows x 17 columns]

# %%
plt.figure(figsize=(22,10))
sns.countplot(data=df_Mexico_Summer, x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %% [markdown]
# <div class="alert alert-success">
#
# 3. Encontrar el numero total de medallas de oro, plata y bronce. Mostrar también los resultados en forma grafica.
# </div>

# %%
count_medals = df_Mexico['Medal'].value_counts().reset_index( name = 'Medal' )
count_medals
# Out:
#     index  Medal
# 0  Bronze     54
# 1    Gold     30
# 2  Silver     26

# %%
number = count_medals.sum()
Total_number = number.unique()[1]
print("El numero total de medallas de bronce oro y plata es de",Total_number)
# Out:
# El numero total de medallas de bronce oro y plata es de 110

# %%
g = sns.catplot(x="index", y="Medal", data= count_medals,
                height=8, kind="bar")

g.set_xlabels("Medallas ")
g.set_ylabels("Numero de medallas")
plt.title('Medallas Mexico')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
#
# 4. Encontrar a los deportistas mexicanos con 2 o más medallas. Mostrar también los resultados en forma grafica.
# </div>

# %%
df_Mexico
# Out:
#         NOC  region notes      ID                               Name Sex  \
# 167721  MEX  Mexico   NaN      82             Enrique Abaroa Martnez   M
# 167722  MEX  Mexico   NaN      98                      Hctor Abaunza   M
# 167723  MEX  Mexico   NaN      98                      Hctor Abaunza   M
# 167724  MEX  Mexico   NaN      98                      Hctor Abaunza   M
# 167725  MEX  Mexico   NaN     405           Jos Javier Abella Fanjul   M
# ...     ...     ...   ...     ...                                ...  ..
# 170596  MEX  Mexico   NaN  134358                 Omar Zepeda de Lon   M
# 170597  MEX  Mexico   NaN  134383            Jos Luis Zertuche Chvez   M
# 170598  MEX  Mexico   NaN  134967                Pablo Zierold Reyes   M
# 170599  MEX  Mexico   NaN  135062  Antonio Lus "Zinha" Naelson Matas   M
# 170600  MEX  Mexico   NaN  135421    Goretti Alejandra Zumaya Flores   F
#
#          Age  Height  Weight    Team        Games  Year  Season  \
# 167721  26.0   183.0    75.0  Mexico  2000 Summer  2000  Summer
# 167722  30.0   169.0    75.0  Mexico  1968 Summer  1968  Summer
# 167723  30.0   169.0    75.0  Mexico  1968 Summer  1968  Summer
# 167724  30.0   169.0    75.0  Mexico  1968 Summer  1968  Summer
# 167725  22.0   176.0    66.0  Mexico  2016 Summer  2016  Summer
# ...      ...     ...     ...     ...          ...   ...     ...
# 170596  39.0   175.0    70.0  Mexico  2016 Summer  2016  Summer
# 170597  27.0   172.0    71.0  Mexico  2000 Summer  2000  Summer
# 170598   NaN   173.0     NaN  Mexico  1932 Summer  1932  Summer
# 170599  28.0   163.0    66.0  Mexico  2004 Summer  2004  Summer
# 170600  19.0   165.0    65.0  Mexico  2016 Summer  2016  Summer
#
#                   City      Sport                                   Event  \
# 167721          Sydney     Tennis                    Tennis Men's Doubles
# 167722     Mexico City    Fencing          Fencing Men's Foil, Individual
# 167723     Mexico City    Fencing                Fencing Men's Foil, Team
# 167724     Mexico City    Fencing               Fencing Men's Sabre, Team
# 167725  Rio de Janeiro   Football                 Football Men's Football
# ...                ...        ...                                     ...
# 170596  Rio de Janeiro  Athletics      Athletics Men's 50 kilometres Walk
# 170597          Sydney     Boxing         Boxing Men's Light-Middleweight
# 170598     Los Angeles   Swimming  Swimming Men's 200 metres Breaststroke
# 170599          Athina   Football                 Football Men's Football
# 170600  Rio de Janeiro   Shooting   Shooting Women's Air Rifle, 10 metres
#
#        Medal
# 167721   NaN
# 167722   NaN
# 167723   NaN
# 167724   NaN
# 167725   NaN
# ...      ...
# 170596   NaN
# 170597   NaN
# 170598   NaN
# 170599   NaN
# 170600   NaN
#
# [2880 rows x 17 columns]

# %%
df_Mexico_na_Medals = df_Mexico.dropna(subset = ['Medal'])
df_new = df_Mexico_na_Medals['Name'].value_counts().reset_index(name='Medal')
df_new
# Out:
#                                  index  Medal
# 0                  Joaqun Capilla Prez      4
# 1   Mara del Rosario Espinoza Espinoza      3
# 2               Humberto Mariles Corts      3
# 3              Germn Sal Snchez Snchez      2
# 4       Paola Milagros Espinosa Snchez      2
# ..                                 ...    ...
# 93        Carlos Armando Girn Gutirrez      1
# 94       Juan lvaro Jos Gaxiola Robles      1
# 95         Ivn Alejandro Garca Navarro      1
# 96                 Ral Fernndez Robert      1
# 97               Agustn Zaragoza Reyna      1
#
# [98 rows x 2 columns]

# %%
df_2ormore = df_new[df_new['Medal'] > 1 ]
df_2ormore
# Out:
#                                 index  Medal
# 0                 Joaqun Capilla Prez      4
# 1  Mara del Rosario Espinoza Espinoza      3
# 2              Humberto Mariles Corts      3
# 3             Germn Sal Snchez Snchez      2
# 4      Paola Milagros Espinosa Snchez      2
# 5                   Rubn Uriza Castro      2
# 6            Joaqun Prez de las Heras      2
# 7                Ral Gonzlez Rodrguez      2

# %%
g = sns.catplot(x="index", y="Medal", data=df_2ormore,
                height=20, kind="bar", palette="muted")
g.set_xlabels("Medallas ")
g.set_ylabels("Numero de medallas ")
plt.title('Medallas Mexico')
plt.show()

# %% [markdown]
# # Ejercicio
#
# **Parte 2**
#
# *Utilizar todos los datos*

# %% [markdown]
# <div class="alert alert-success">
#
# 5. Encontrar a los 5 deportistas con más medallas de oro en los juegos de Verano. Mostrar también los resultados en forma grafica.
# </div>

# %%
df_medals_summer = df[df['Season']=='Summer']
df_5moremedals=df_medals_summer['Name'].value_counts().reset_index(name='Medals')
df_5moremedals = df_5moremedals.head()
df_5moremedals
# Out:
#                       index  Medals
# 0      Robert Tait McKenzie      58
# 1  Heikki Ilmari Savolainen      39
# 2     Joseph "Josy" Stoffel      38
# 3       Ioannis Theofilakis      36
# 4               Takashi Ono      33

# %%
g = sns.catplot(x="index", y="Medals", data=df_5moremedals,
                height=20, kind="bar", palette="muted")
g.set_xlabels("Atletas ")
g.set_ylabels("Medallas ")
plt.title('Jugadores con mas medallas')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# 6. Encontrar el deportista (o deportistas) más joven en ganar un medalla de oro, también mencionar: la edad, año de obtención, disciplina y juegos (verano o invierno,).
# </div>

# %%
gold_medals=df[df['Medal']=='Gold']

gold_medals = gold_medals.dropna( subset = ['Age'] )

gold_medals = gold_medals[['Name','Age','Year','Sport','Season']]


gold_medals.sort_values(by=['Age']).head()
# Out:
#                                       Name   Age  Year     Sport  Season
# 252929        Marjorie Gestring (-Redlick)  13.0  1936    Diving  Summer
# 44579                           Fu Mingxia  13.0  1992    Diving  Summer
# 250917  Donna Elizabeth de Varona (-Pinto)  13.0  1960  Swimming  Summer
# 116996                         Klaus Zerta  13.0  1960    Rowing  Summer
# 213544                       Hans Bourquin  13.0  1928    Rowing  Summer

# %% [markdown]
# <div class="alert alert-success">
#
# 7. Mostrar en una grafica de dispersión el peso Vs altura de los deportistas.
#
# * Puede utilizar sns.scatterplot (https://seaborn.pydata.org/generated/seaborn.scatterplot.html)
# </div>

# %%
sns.scatterplot(data=df, x="Weight", y="Height", hue="Medal", style="Medal")
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Height'>

# %% [markdown]
# <div class="alert alert-success">
#
# 8. ¿Qué deporte ha tenido el mayor número de participantes  en toda su historia (contando solo lo reportado en el archivo)?
#
# </div>

# %%
sports=df['Sport'].value_counts().reset_index(name='Players')
sports
# Out:
#             index  Players
# 0       Athletics    38596
# 1      Gymnastics    26703
# 2        Swimming    23052
# 3        Shooting    11432
# 4         Cycling    10859
# ..            ...      ...
# 61       Racquets       12
# 62   Jeu De Paume       11
# 63          Roque        4
# 64  Basque Pelota        2
# 65    Aeronautics        1
#
# [66 rows x 2 columns]

# %% [markdown]
# ATLETISMO HA SIDO EL DEPORTE CON MAYOR PARTICIPANTES
